# %% [markdown]
# # Spectrogram extraction

# %%
import os
from pathlib import Path
import pickle
import numpy as np
from utils import extract_spectrogram
import matplotlib.pyplot as plt
import random
from PIL import Image

# %% [markdown]
# ## 1 - Setting global variables

# %%
db_directory = Path(r"C:\Study\DB\SpeechCommands")
ignore_list = [
    r"C:\Study\DB\SpeechCommands\_background_noise_"
]
random.seed(1)

# %% [markdown]
# ## 2 - Getting list of all sound files in db

# %%
file_list = [f for f in db_directory.resolve().glob('**/*') if f.is_file() and f.suffix == '.wav'  and 
             all(ignore_obj not in str(f) for ignore_obj in ignore_list)]

# %% [markdown]
# ### Shuffle filenames

# %%
random.shuffle(file_list)

# %% [markdown]
# ## 3 - Spectrogram extraction

# %%
spectrograms = []
for i, f in enumerate(file_list):
    print("\r{} out of {}".format(i + 1, len(file_list)), end='')
    spectrogram = extract_spectrogram(f)
    spectrograms.append(spectrogram)
print("\nextraction finished")

# with open('spectrograms_4.pickle', 'wb') as f:
#     pickle.dump(spectrograms, f, pickle.HIGHEST_PROTOCOL)
# print("saving finished")

with open('file_list_4.pickle', 'wb') as f:
    pickle.dump(file_list, f, pickle.HIGHEST_PROTOCOL)
print("saving finished")
# Out:
# 42 out of 64721
# C:\Study\SOM\utils.py:10: RuntimeWarning: divide by zero encountered in log10
#   dBS = 20 * np.log10(spectogram)
# 64721 out of 64721
# extraction finished
# saving finished
# saving finished

# %% [markdown]
# ## 4 - Pad or crop to the same length

# %%
sample_length = 150
for i, s in enumerate(spectrograms):
    print("\r{} out of {}".format(i + 1, len(spectrograms)), end='')
    length = s.shape[-1]
    if length < 150:
        # pad
        s = np.pad(s, ((0, 0), (0, sample_length - length)), 'constant', constant_values=(0.))
    else:
        s = s[:,:sample_length]
    spectrograms[i] = s
print("\npadding finished")
# Out:
# 64721 out of 64721
# padding finished

# %% [markdown]
# ## 5 - Stack samples

# %%
s = np.stack(spectrograms, axis=0)

# %% [markdown]
# ## 6 - Norm values

# %%
spectrograms_norm = s / np.max(s)

# %% [markdown]
# ## 7 - See some exmaples

# %%
% matplotlib inline
# plt.imshow(spectrograms[0])
random.seed(1)
idx = list(range(len(spectrograms_norm)))
random.shuffle(idx)
idx = idx[:7]
for i in idx:
    plt.pcolormesh(spectrograms_norm[i])
    plt.colorbar()
    plt.title("{} \ {}".format(file_list[i].parent.stem, file_list[i].stem))
    plt.show()

# %% [markdown]
# ## 7 - Flatten values

# %%
spectrograms_flatten = spectrograms_norm.reshape(-1, spectrograms_norm.shape[0]).T
print("shape of the spectrograms array: ", spectrograms_norm.shape)
print("shape of the flattened spectrograms array: ", spectrograms_flatten.shape)
# Out:
# shape of the spectrograms array:  (64721, 257, 150)
# shape of the flattened spectrograms array:  (64721, 38550)

# %% [markdown]
# ## 8 - Save training set

# %%
with open('spectrograms_4_training.pickle', 'wb') as f:
    pickle.dump(spectrograms_flatten, f, pickle.HIGHEST_PROTOCOL)
print("training set saved")
# Out:
# training set saved

# %% [markdown]
# ## 9 - Split data to training and test sets

# %%
testing_list_fname = str(db_directory) + r"\testing_list.txt"
validation_list_fname = str(db_directory) + r"\validation_list.txt"

# %% [markdown]
# ## 10 - Saving images to a directory (optional)

# %%
directory_for_images = "images"
print("saving images...")
idx = 1
for spec, fname in zip(spectrograms_norm, file_list):
    print("\rsaving {} out of {}".format(idx, len(file_list)), end='')
    path = "{}\{}\{}.png".format(directory_for_images, fname.parent.stem, fname.stem)
    im = Image.fromarray(spec * 255)
    if im.mode != "RGB":
        im = im.convert("RGB")
    try:
        os.mkdir("{}\{}".format(directory_for_images, fname.parent.stem))
    except FileExistsError:
        pass
    im.save(path)
    idx += 1
# Out:
# saving images...
# saving 64721 out of 64721
